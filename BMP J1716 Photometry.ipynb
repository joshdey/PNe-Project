# %%
tpf = KeplerTargetPixelFile('../Data/ktwo251248524-c111_lpd-targ.fits')

# %%
tpf.interact()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a4d64095-7927-47a4-afc4-b9f48d1b115d">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e7172f45-8ffe-4369-af4c-240b256b1c05"></div>
# </div>
# ...
# Output()

# %%
tpf.plot(frame=527, interpolation='nearest')
